# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Finance Key Skills

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## Data Types

# %% [markdown]
# ### `int` Objects

# %%
# !git clone https://github.com/tpq-classes/pff_key_skills.git
import sys
sys.path.append('pff_key_skills')

# %%
4

# %%
44

# %%
print(100)

# %%
type(5)

# %%
type(-8)

# %%
5 + 6

# %%
5 - 6

# %%
5 * 6

# %%
5 / 6

# %%
5 ** 6  # power

# %%
a = 121  # assignment

# %%
a

# %%
type(a)

# %%
a * 10

# %%
a ** 2

# %%
b = 8

# %%
2 ** b

# %%
2 ** a

# %%
10 ** 100  # googol number

# %%
a.bit_length()

# %%
(10 ** 100).bit_length()

# %%
a.as_integer_ratio()

# %%
a.numerator

# %%
a.denominator

# %%
c = 12345

# %%
c.as_integer_ratio()

# %% [markdown]
# ### `float` Objects

# %%
2.5

# %%
11.1111

# %%
type(11.1)

# %%
2.

# %%
type(2.)

# %%
2.6 * 3.4

# %%
2.7 ** 2

# %%
round(2.7 ** 2, 3)  # rounds to a maximum (!) of three digits

# %%
2.7 ** 2.8

# %%
d = 2.9999

# %%
type(d)

# %%
d

# %%
d / 3.5

# %%
d * 2

# %%
(2 / 3)

# %%
type(2 / 3)

# %%
float(2)

# %%
e = int(2.5)

# %%
e

# %%
type(e)

# %%
d.is_integer()

# %%
(2.).is_integer()

# %%
d.as_integer_ratio()

# %%
numerator, denominator = d.as_integer_ratio()

# %%
numerator / denominator

# %%
d.hex()

# %% [markdown]
# ### `str` Object

# %%
'a'

# %%
'python'

# %%
type('A')

# %%
type('Python')

# %%
'Pyt' + 'hon'

# %%
# 'Pyt' * 'hon'  # does not work

# %%
'Python ' * 10

# %%
55 * '='

# %%
# 'Does not work.' ** 2

# %%
"This is also a str object with double quotes."

# %%
ml = '''This is a
multiline str object
which goes over multiple
lines.'''

# %%
ml  # \n newline operator

# %%
print(ml)

# %%
"""This is
another example"""

# %%
s = "Python"

# %%
s.find('h')

# %%
s[3]

# %%
# s.find?

# %%
# help(s.find)

# %%
s.lower()

# %%
s.upper()

# %%
s[0]  # Python uses zero-based numbering

# %%
s[1]

# %%
len(s)  # length of the object = number of "base" elements

# %%
s[len(s) - 1] # final "base" element

# %%
s[-1]  # final "base" element

# %%
s

# %%
s[2:5]  # index 5 excluded

# %%
s[2] + s[3] + s[4]

# %%
s[2:]

# %%
s[:4]

# %%
s[:3]

# %%
s[3:]

# %%
s[:3] + s[3:]

# %%
s[-1]

# %%
s[-2]

# %%
s[-4:-2]

# %%
s[2:6:2]  # start:end(excluded):step size

# %%
s[:]

# %%
s[::-1]  # reversing the string (order of characters)

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="mailto:training@tpq.io">training@tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
