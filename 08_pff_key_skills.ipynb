# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Finance Key Skills

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## NumPy Package

# %% [markdown]
# ### Resizing Revisited

# %%
# !git clone https://github.com/tpq-classes/pff_key_skills.git
import sys
sys.path.append('/content/pff_key_skills')

# %%
# !cat /content/resize.py

# %%
# %run /content/pff_key_skills/resize.py

# %%
c = np.arange(10)

# %%
print(c)

# %%
c.resize((5,))

# %%
c

# %%
c = np.arange(10)

# %%
c

# %%
c.resize((5,), refcheck=False)

# %%
c

# %% [markdown]
# ### Creating `ndarray` Objects

# %%
l = [1, 3, 5, 6]

# %%
np.array(l)

# %%
np.arange(15)

# %%
np.linspace(5, 15, 20)

# %%
np.zeros(10)

# %%
np.ones(10)

# %%
np.empty(10)

# %%
a = np.empty(1_000_000_000)

# %%
a

# %%
np.sum(a)

# %%
# np.zeros?

# %%
np.zeros(10)

# %%
np.zeros((2, 10))

# %%
np.zeros((10, 2))

# %%
np.zeros((2, 10), dtype=np.int8)

# %%
np.zeros((2, 10), dtype=np.int32)

# %%
np.ones(10)

# %%
np.ones(10, dtype=np.int32)

# %%
l = [(1, 2, 3), (6, 7., 8)]
l

# %%
np.array(l)

# %%
np.arange(20).reshape(4, 5)

# %%
b = np.linspace(0, 15, 15).reshape(5, 3)

# %%
b

# %% [markdown]
# ### Operations on 2d Array Objects

# %%
b.sum()

# %%
b.mean()

# %%
b.sum(axis=0)

# %%
b.sum(axis=1)

# %%
b.mean(axis=0)

# %%
b.mean(axis=1)

# %%
np.sqrt(b)

# %%
b * 2

# %%
b ** 2

# %%
np.set_printoptions(suppress=True)

# %%
2 ** b

# %%
b ** b

# %%
b * b

# %% [markdown]
# ### Boolean Operations

# %%
a  = np.arange(15)
a

# %%
b

# %%
x = 10

# %%
x > 5

# %%
x < 7

# %%
a > 5  # element-wise operations

# %%
b > 5

# %%
a < 7

# %%
b < 7

# %%
a == 7

# %%
a != 7

# %% [markdown]
# ### Indexing & Selection

# %%
a

# %%
b

# %%
a[0]

# %%
a[-1]

# %%
b[0]

# %%
b[-1]

# %%
b[0, 0]  # first row, first column

# %%
b[-1, -1]  # last row, last column

# %%
b[:, 1]  # second column

# %%
b[:, 1:3]  # second & third column

# %%
b[2:4, 1:3]  # third & fourth row + second & third column

# %%
b[2:4, 1:3] ** 2

# %%
b[2:4, 1:3].sum()

# %%
np.sqrt(b[2:4, 1:3])

# %%
a > 5

# %%
a[a > 5]

# %%
a[a <= 5]

# %%
b

# %%
b.shape

# %%
r = b[b > 5]
r

# %%
r.shape

# %% [markdown]
# ### Changing the Shape

# %%
b.flatten()  # gives 1d array object from 2d one

# %%
b

# %%
b.transpose()

# %%
b.T

# %%
b.reshape(3, 5)

# %% [markdown]
# ### Random Number Generation

# %% [markdown]
# #### Pure Python

# %%
import random

# %%
random.random()  # uniformly distributed (pseudo-)random number (between 0 and 1)

# %%
[random.random() for _ in range(10)]

# %%
random.gauss(0, 1)  # standard normally distributed random number

# %%
[random.gauss(0, 1) for _ in range(10)]

# %% [markdown]
# #### With NumPy

# %%
from numpy.random import default_rng

# %%
rng = default_rng()

# %%
rng.random()  # uniformly distributed (pseudo-)random number

# %%
rng.random(10)

# %%
rng.random((5, 3))

# %%
rng.standard_normal()  # standard-normally distributed (pseudo-)random number

# %%
rng.standard_normal(10)

# %%
rng.standard_normal((5, 3))

# %% [markdown]
# #### Speed Comparison

# %%
N = 1_000_000

# %%
# %time rnp = [random.gauss(0, 1) for _ in range(N)]

# %%
# %timeit rnp = [random.gauss(0, 1) for _ in range(N)]

# %%
np.array(rnp).mean()

# %%
np.array(rnp).std()

# %%
# %time rnn = rng.standard_normal(N)

# %%
# %timeit rnn = rng.standard_normal(N)

# %%
rnn.mean()

# %%
rnn.std()

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="mailto:training@tpq.io">training@tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
