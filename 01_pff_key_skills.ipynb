# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Finance Key Skills

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## Docker

# %% [markdown]
# Starting a Docker container:
#
#     docker run -ti -h keyskills -v $(pwd):/root/live -p 9999:9999 ubuntu:latest /bin/bash

# %% [markdown]
# ## Check Python Packages

# %%
# !git clone https://github.com/tpq-classes/pff_key_skills.git
import sys
sys.path.append('pff_key_skills')

# %%
import numpy as np
import pandas as pd

# %%
a = np.linspace(0, 15).reshape(10, 5)  # creating an ndarray object

# %%
a
# Out:
# array([[ 0.        ,  0.30612245,  0.6122449 ,  0.91836735,  1.2244898 ],
#        [ 1.53061224,  1.83673469,  2.14285714,  2.44897959,  2.75510204],
#        [ 3.06122449,  3.36734694,  3.67346939,  3.97959184,  4.28571429],
#        [ 4.59183673,  4.89795918,  5.20408163,  5.51020408,  5.81632653],
#        [ 6.12244898,  6.42857143,  6.73469388,  7.04081633,  7.34693878],
#        [ 7.65306122,  7.95918367,  8.26530612,  8.57142857,  8.87755102],
#        [ 9.18367347,  9.48979592,  9.79591837, 10.10204082, 10.40816327],
#        [10.71428571, 11.02040816, 11.32653061, 11.63265306, 11.93877551],
#        [12.24489796, 12.55102041, 12.85714286, 13.16326531, 13.46938776],
#        [13.7755102 , 14.08163265, 14.3877551 , 14.69387755, 15.        ]])

# %%
df = pd.DataFrame(a)  # creating a DataFrame object

# %%
df
# Out:
#            0          1          2          3          4
# 0   0.000000   0.306122   0.612245   0.918367   1.224490
# 1   1.530612   1.836735   2.142857   2.448980   2.755102
# 2   3.061224   3.367347   3.673469   3.979592   4.285714
# 3   4.591837   4.897959   5.204082   5.510204   5.816327
# 4   6.122449   6.428571   6.734694   7.040816   7.346939
# 5   7.653061   7.959184   8.265306   8.571429   8.877551
# 6   9.183673   9.489796   9.795918  10.102041  10.408163
# 7  10.714286  11.020408  11.326531  11.632653  11.938776
# 8  12.244898  12.551020  12.857143  13.163265  13.469388
# 9  13.775510  14.081633  14.387755  14.693878  15.000000

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="mailto:training@tpq.io">training@tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
