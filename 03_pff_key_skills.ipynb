# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Finance Key Skills

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## Data Structures

# %% [markdown]
# ### `tuple` Object

# %%
# !git clone https://github.com/tpq-classes/pff_key_skills.git
import sys
sys.path.append('pff_key_skills')

# %%
t = 1, 2, 3, 4

# %%
t

# %%
type(t)

# %%
t = 1, 2.5, 'python'

# %%
t

# %%
type(t)

# %%
t = ('a', 'b', 10)

# %%
t.count?

# %%
t.count(11)

# %%
t.count(10)

# %%
t.index?

# %%
t.index(10)

# %%
t[0]

# %%
t[1]

# %%
t[:2]

# %%
range(10)

# %%
range?

# %%
tuple(range(10))

# %%
tuple(range(10, 25, 2))

# %%
t = tuple(range(2, 12))

# %%
t[5]

# %%
# t[5] = 10  # does not work, tuple objects are "immutable"

# %%
('abc', 10, t, t)  # tuple objects in tuple object

# %%
t_ = t[:4]

# %%
t_

# %%
t + t

# %%
2 * t

# %% [markdown]
# ### `list` Object

# %%
l = [1, 2, 3, 4]

# %%
l

# %%
type(l)

# %%
l = [1, 2.5, 10.75, 'abc', l, t, True]

# %%
l

# %%
list(range(2, 12))

# %%
l.remove?

# %%
l.remove('abc')  # list objects are mutable

# %%
l

# %%
l.append('abcd')

# %%
l

# %%
l.pop?

# %%
l.pop()

# %%
l.insert?

# %%
l.insert(2, 'inserted')

# %%
l

# %%
l.reverse?

# %%
l.reverse()

# %%
l

# %%
l[0] = False  # list objects are mutable

# %%
l

# %%
tuple(l)

# %%
list(t)

# %%
l + [1, 2, 3, 4]

# %%
2 * l

# %%
l[:4]

# %%
l[4:]

# %% [markdown]
# ### `set` Object

# %%
{1, 2, 3, 4}

# %%
s = {1, 2, 3, 5, 8}

# %%
type(s)

# %%
s = {1, 2, 2, 2, 2, 3, 5, 5, 8, 8, 8, 8, 8}

# %%
s

# %%
set([2, 2, 2, 3, 3, 3, 3, 5, 5])

# %%
{9, 5, 6, 6, 6, 3, 3, 3}

# %%
s1 = set(range(10))
s1

# %%
s2 = set(range(5, 15))
s2

# %%
s1.union?

# %%
s1.union(s2)

# %%
s1.intersection(s2)

# %%
s1.symmetric_difference(s2)

# %% [markdown]
# ### `dict` Object

# %%
d = {'a': 1234, 'b': 2345, 'c': 3456}

# %%
d

# %%
type(d)

# %%
d['b']

# %%
d.clear?

# %%
d.keys()

# %%
d.values()

# %%
list(d.values())

# %%
list(d.values())[0]

# %%
d.items()

# %%
tuple(d.items())

# %%
tuple(d.items())[1]

# %%
d

# %%
list(d)

# %%
tuple(d)

# %%
d['b'] = 78910

# %%
d

# %%
# l

# %%
# dict(l)

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="mailto:training@tpq.io">training@tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
